# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# This is the week 3, Peer-graded Assignment for Applied Data Science Capstone in
# Coursera.

# %% [markdown]
# ## Table of Contents
#
#
# 1.  Scraping the list of postal codes in Canada from the Wikipedia -https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M,<br>
#
# 2.  Creating a dataframe <br>
#
# 3.  Removing cells with  'Not assigned' and combining rows with the same postal code. <br>
#
# 4.  Using the .shape method to print the number of rows of the dataframe.. <br>

# %% [markdown]
# #### Step 1 - Scraping the data from Wikipedia

# %%
#importing libraries
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Using requests library to download the webpage from https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M, and Saving it in the variable named 'data'.

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
data=requests.get(url)

# %%
soup = BeautifulSoup(data.content, 'html.parser')
table=soup.find('table')

# %% [markdown]
# #### Step 2 Creating a dataframe that consist of three columns -  PostalCode, Borough, and Neighborhood

# %%
column_names = ['Postalcode','Borough','Neighbourhood']
new_df = pd.DataFrame(columns = column_names)

# %%
# getting the postcode, borough, neighborhood 
for tr_cell in table.find_all('tr'):
    row_data=[]
    for td_cell in tr_cell.find_all('td'):
        row_data.append(td_cell.text.strip())
    if len(row_data)==3:
        new_df.loc[len(new_df)] = row_data

# %%
new_df.head(20)
# Out:
#    Postalcode           Borough  \
# 0         M1A      Not assigned
# 1         M2A      Not assigned
# 2         M3A        North York
# 3         M4A        North York
# 4         M5A  Downtown Toronto
# 5         M6A        North York
# 6         M7A  Downtown Toronto
# 7         M8A      Not assigned
# 8         M9A         Etobicoke
# 9         M1B       Scarborough
# 10        M2B      Not assigned
# 11        M3B        North York
# 12        M4B         East York
# 13        M5B  Downtown Toronto
# 14        M6B        North York
# 15        M7B      Not assigned
# 16        M8B      Not assigned
# 17        M9B         Etobicoke
# 18        M1C       Scarborough
# 19        M2C      Not assigned
#
#                                         Neighbourhood
# 0                                        Not assigned
# 1                                        Not assigned
# 2                                           Parkwoods
# 3                                    Victoria Village
# ...

# %% [markdown]
# #### Step 3 Data Cleaning.
#
# Removing the 'Not assigned' in borough

# %%
# Get names of indexes for which column Borough has value "Not assigned"
remove_df = new_df[ new_df['Borough'] =='Not assigned'].index
# Delete these row indexes from dataFrame
new_df.drop(remove_df  , inplace=True)
new_df.head(20)
# Out:
#    Postalcode           Borough  \
# 2         M3A        North York
# 3         M4A        North York
# 4         M5A  Downtown Toronto
# 5         M6A        North York
# 6         M7A  Downtown Toronto
# 8         M9A         Etobicoke
# 9         M1B       Scarborough
# 11        M3B        North York
# 12        M4B         East York
# 13        M5B  Downtown Toronto
# 14        M6B        North York
# 17        M9B         Etobicoke
# 18        M1C       Scarborough
# 20        M3C        North York
# 21        M4C         East York
# 22        M5C  Downtown Toronto
# 23        M6C              York
# 26        M9C         Etobicoke
# 27        M1E       Scarborough
# 30        M4E      East Toronto
#
#                                         Neighbourhood
# 2                                           Parkwoods
# 3                                    Victoria Village
# 4                           Regent Park, Harbourfront
# 5                    Lawrence Manor, Lawrence Heights
# ...

# %% [markdown]
# Removing the 'Not assigned' in Neighbourhood

# %%
#droping the 'Not assigned' in the Neighbourhood columne
new_df.loc[new_df['Neighbourhood'] =='Not assigned','Neighbourhood'] = new_df['Borough']
new_df.head(20)
# Out:
#    Postalcode           Borough  \
# 2         M3A        North York
# 3         M4A        North York
# 4         M5A  Downtown Toronto
# 5         M6A        North York
# 6         M7A  Downtown Toronto
# 8         M9A         Etobicoke
# 9         M1B       Scarborough
# 11        M3B        North York
# 12        M4B         East York
# 13        M5B  Downtown Toronto
# 14        M6B        North York
# 17        M9B         Etobicoke
# 18        M1C       Scarborough
# 20        M3C        North York
# 21        M4C         East York
# 22        M5C  Downtown Toronto
# 23        M6C              York
# 26        M9C         Etobicoke
# 27        M1E       Scarborough
# 30        M4E      East Toronto
#
#                                         Neighbourhood
# 2                                           Parkwoods
# 3                                    Victoria Village
# 4                           Regent Park, Harbourfront
# 5                    Lawrence Manor, Lawrence Heights
# ...

# %% [markdown]
# Combining the rows with the same postal code and separating them with a comma.

# %%
com_data = new_df.groupby(['Postalcode','Borough'], sort=False).agg( ', '.join)

# %%
df=com_data.reset_index()
df.head(20)
# Out:
#    Postalcode           Borough  \
# 0         M3A        North York
# 1         M4A        North York
# 2         M5A  Downtown Toronto
# 3         M6A        North York
# 4         M7A  Downtown Toronto
# 5         M9A         Etobicoke
# 6         M1B       Scarborough
# 7         M3B        North York
# 8         M4B         East York
# 9         M5B  Downtown Toronto
# 10        M6B        North York
# 11        M9B         Etobicoke
# 12        M1C       Scarborough
# 13        M3C        North York
# 14        M4C         East York
# 15        M5C  Downtown Toronto
# 16        M6C              York
# 17        M9C         Etobicoke
# 18        M1E       Scarborough
# 19        M4E      East Toronto
#
#                                         Neighbourhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                           Regent Park, Harbourfront
# 3                    Lawrence Manor, Lawrence Heights
# ...

# %% [markdown]
# #### Step 4 using the .shape method to print the number of rows of the dataframe

# %%
df.shape
# Out:
# (103, 3)
